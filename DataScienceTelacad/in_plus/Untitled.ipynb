# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbs
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

df = pd.read_csv('test.csv')
print(df.head())

#df.info()

print(df.describe())

sbs.boxplot(df['x'])
plt.show()
sbs.boxplot(df['y'])
plt.show()

x = df.drop('y', axis=1)
print(x)

y = df['y']
print(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 101)
print('X ANTRENARE')
print(x_train)
print('X TESTARE')
print(x_test)

lm = LinearRegression()
lm.fit(x_train, y_train)

print(lm.intercept_)
print(lm.coef_)

coeficienti = pd.DataFrame(lm.coef_, x.columns)
coeficienti.columns=['Coeficienti']
print(coeficienti)

y_pred = lm.predict(x_test)

plt.scatter(y_test, y_pred, color='blue')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

sbs.distplot(y_pred - y_test)
plt.show()

print('MSE: ', metrics.mean_squared_error(y_test, y_pred))
print('MSE: ', metrics.mean_squared_error(y_test, y_pred))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('MAE: ', metrics.mean_absolute_error(y_test, y_pred))

lm.predict([[3, 50]])
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864
#                 x           y
# count  300.000000  300.000000
# mean    50.936667   51.205051
# std     28.504286   29.071481
# min      0.000000   -3.467884
# 25%     27.000000   25.676502
# 50%     53.000000   52.170557
# 75%     73.000000   74.303007
# max    100.000000  105.591837
#       x
# 0    77
# 1    21
# 2    22
# 3    20
# 4    36
# ..   ..
# 295  71
# 296  46
# 297  55
# 298  62
# 299  47
#
# [300 rows x 1 columns]
# 0      79.775152
# 1      23.177279
# 2      25.609262
# 3      17.857388
# 4      41.849864
#          ...
# 295    68.545888
# 296    47.334876
# 297    54.090637
# 298    63.297171
# 299    52.459467
# Name: y, Length: 300, dtype: float64
# X ANTRENARE
#        x
# 34    28
# 1     21
# 133   25
# 283   21
# 279   23
# ..   ...
# 40    91
# 75    28
# 87   100
# 63    61
# 11    19
#
# [210 rows x 1 columns]
# X TESTARE
#       x
# 176  58
# 250  21
# 12   96
# 16   65
# 258  67
# ..   ..
# 282  64
# 242  54
# 119   0
# 57   64
# 37   69
#
# [90 rows x 1 columns]
# -0.7071623560748463
# [1.01616788]
#    Coeficienti
# x     1.016168
# C:\Users\cosmi\AppData\Local\Temp\ipykernel_13272\807937546.py:50: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbs.distplot(y_pred - y_test)
# D:\Program_Files\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# MSE:  10.268405673005624
# MSE:  10.268405673005624
# RMSE:  3.2044353126573837
# MAE:  2.5257412888477733
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 58
#      55 print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
#      56 print('MAE: ', metrics.mean_absolute_error(y_test, y_pred))
# ---> 58 lm.predict([[3, 50]])
#
# File D:\Program_Files\python\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File D:\Program_Files\python\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File D:\Program_Files\python\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File D:\Program_Files\python\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 2 features, but LinearRegression is expecting 1 features as input.
